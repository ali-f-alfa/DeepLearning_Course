# %%
import tensorflow as tf
import matplotlib.pyplot as plt      


from tensorflow.keras import layers
from tensorflow.keras import regularizers

# !pip install -q git+https://github.com/tensorflow/docs
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')
# Out:
# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz
# 2816409600/2816407858 [==============================] - 141s 0us/step
# 2816417792/2816407858 [==============================] - 141s 0us/step

# %%
FEATURES = 28
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %%
model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 16)                464
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_callbacks():
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=200),
  ]

# %%
def compile_and_fit(model, max_epochs=10000):
  model.compile(optimizer="adam",
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(),
    verbose=0)
  return history

# %%
h = compile_and_fit(model)

plt.figure(figsize=(5, 5))

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 16)                464
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4755,  binary_crossentropy:0.7566,  loss:0.7566,  val_accuracy:0.4960,  val_binary_crossentropy:0.7175,  val_loss:0.7175,
# ....................................................................................................
# Epoch: 100, accuracy:0.6030,  binary_crossentropy:0.6241,  loss:0.6241,  val_accuracy:0.5660,  val_binary_crossentropy:0.6203,  val_loss:0.6203,
# ....................................................................................................
# Epoch: 200, accuracy:0.6245,  binary_crossentropy:0.6102,  loss:0.6102,  val_accuracy:0.6200,  val_binary_crossentropy:0.6070,  val_loss:0.6070,
# ....................................................................................................
# Epoch: 300, accuracy:0.6529,  binary_crossentropy:0.5976,  loss:0.5976,  val_accuracy:0.6410,  val_binary_crossentropy:0.5965,  val_loss:0.5965,
# ....................................................................................................
# Epoch: 400, accuracy:0.6668,  binary_crossentropy:0.5893,  loss:0.5893,  val_accuracy:0.6240,  val_binary_crossentropy:0.5940,  val_loss:0.5940,
# ....................................................................................................
# Epoch: 500, accuracy:0.6702,  binary_crossentropy:0.5852,  loss:0.5852,  val_accuracy:0.6430,  val_binary_crossentropy:0.5926,  val_loss:0.5926,
# ....................................................................................................
# Epoch: 600, accuracy:0.6726,  binary_crossentropy:0.5816,  loss:0.5816,  val_accuracy:0.6540,  val_binary_crossentropy:0.5924,  val_loss:0.5924,
# ......................................................................

# %%
model2 = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(128, activation='elu'),
    layers.Dense(256, activation='elu'),
    layers.Dense(1)
])

h = compile_and_fit(model2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 16)                464
#
#  dense_10 (Dense)            (None, 64)                1088
#
#  dense_11 (Dense)            (None, 128)               8320
#
#  dense_12 (Dense)            (None, 256)               33024
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 43,153
# Trainable params: 43,153
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4866,  binary_crossentropy:0.6914,  loss:0.6914,  val_accuracy:0.4990,  val_binary_crossentropy:0.6839,  val_loss:0.6839,
# ....................................................................................................
# Epoch: 100, accuracy:0.6837,  binary_crossentropy:0.5658,  loss:0.5658,  val_accuracy:0.6580,  val_binary_crossentropy:0.6019,  val_loss:0.6019,
# ....................................................................................................
# Epoch: 200, accuracy:0.7489,  binary_crossentropy:0.4740,  loss:0.4740,  val_accuracy:0.6540,  val_binary_crossentropy:0.6624,  val_loss:0.6624,
# ................................................................................

# %%
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.show()

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.show()

# %%
model3 = tf.keras.Sequential([
    layers.Dense(16, activation='elu', kernel_regularizer=regularizers.l2(0.001), input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(128, activation='elu',kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(256, activation='elu',kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

h = compile_and_fit(model3)

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.show()

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 16)                464
#
#  dense_20 (Dense)            (None, 64)                1088
#
#  dense_21 (Dense)            (None, 128)               8320
#
#  dense_22 (Dense)            (None, 256)               33024
#
#  dense_23 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 43,153
# Trainable params: 43,153
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4984,  binary_crossentropy:0.6902,  loss:0.9755,  val_accuracy:0.4980,  val_binary_crossentropy:0.6832,  val_loss:0.9524,
# ....................................................................................................
# Epoch: 100, accuracy:0.6340,  binary_crossentropy:0.6106,  loss:0.6307,  val_accuracy:0.6580,  val_binary_crossentropy:0.5965,  val_loss:0.6167,
# ....................................................................................................
# Epoch: 200, accuracy:0.6650,  binary_crossentropy:0.5910,  loss:0.6101,  val_accuracy:0.6760,  val_binary_crossentropy:0.5820,  val_loss:0.6010,
# ....................................................................................................
# Epoch: 300, accuracy:0.6672,  binary_crossentropy:0.5845,  loss:0.6032,  val_accuracy:0.6640,  val_binary_crossentropy:0.5807,  val_loss:0.5994,
# ....................................................................................................
# Epoch: 400, accuracy:0.6795,  binary_crossentropy:0.5767,  loss:0.5952,  val_accuracy:0.6810,  val_binary_crossentropy:0.5770,  val_loss:0.5954,
# ....................................................................................................
# Epoch: 500, accuracy:0.6825,  binary_crossentropy:0.5735,  loss:0.5919,  val_accuracy:0.6870,  val_binary_crossentropy:0.5786,  val_loss:0.5970,
# ..........................................................................

# %%
model3 = tf.keras.Sequential([
    layers.Dense(16, activation='elu', kernel_regularizer=regularizers.l2(0.001), input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='elu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(128, activation='elu',kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(256, activation='elu',kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(1)
])

h = compile_and_fit(model3)

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.show()

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 16)                464
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_25 (Dense)            (None, 64)                1088
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_26 (Dense)            (None, 128)               8320
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_27 (Dense)            (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_28 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 43,153
# Trainable params: 43,153
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4889,  binary_crossentropy:0.7945,  loss:1.0887,  val_accuracy:0.4600,  val_binary_crossentropy:0.6908,  val_loss:0.9742,
# ....................................................................................................
# Epoch: 100, accuracy:0.5643,  binary_crossentropy:0.6465,  loss:0.6548,  val_accuracy:0.5410,  val_binary_crossentropy:0.6396,  val_loss:0.6477,
# ....................................................................................................
# Epoch: 200, accuracy:0.5695,  binary_crossentropy:0.6428,  loss:0.6502,  val_accuracy:0.5680,  val_binary_crossentropy:0.6316,  val_loss:0.6387,
# ....................................................................................................
# Epoch: 300, accuracy:0.5740,  binary_crossentropy:0.6424,  loss:0.6493,  val_accuracy:0.5750,  val_binary_crossentropy:0.6268,  val_loss:0.6338,
# ....................................................................................................
# Epoch: 400, accuracy:0.5786,  binary_crossentropy:0.6435,  loss:0.6501,  val_accuracy:0.6080,  val_binary_crossentropy:0.6306,  val_loss:0.6369,
# ....................................................................................................
# Epoch: 500, accuracy:0.5724,  binary_crossentropy:0.6420,  loss:0.6483,  val_accuracy:0.5820,  val_binary_crossentropy:0.6254,  val_loss:0.6319,
# ....................................................................................................
# Epoch: 600, accuracy:0.5706,  binary_crossentropy:0.6403,  loss:0.6466,  val_accuracy:0.5640,  val_binary_crossentropy:0.6289,  val_loss:0.6351,
# ....................................................................................................
# Epoch: 700, accuracy:0.5619,  binary_crossentropy:0.6459,  loss:0.6519,  val_accuracy:0.5650,  val_binary_crossentropy:0.6294,  val_loss:0.6354,
# ....................................................................................................
# Epoch: 800, accuracy:0.5708,  binary_crossentropy:0.6415,  loss:0.6476,  val_accuracy:0.5570,  val_binary_crossentropy:0.6306,  val_loss:0.6366,
# .......................................................

# %%
model3 = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(64, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(256, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

h = compile_and_fit(model3)

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.show()

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 16)                464
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  dense_30 (Dense)            (None, 64)                1088
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_31 (Dense)            (None, 128)               8320
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_32 (Dense)            (None, 256)               33024
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_33 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 43,153
# Trainable params: 43,153
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4881,  binary_crossentropy:0.7908,  loss:0.7908,  val_accuracy:0.4600,  val_binary_crossentropy:0.6846,  val_loss:0.6846,
# ....................................................................................................
# Epoch: 100, accuracy:0.5825,  binary_crossentropy:0.6419,  loss:0.6419,  val_accuracy:0.6310,  val_binary_crossentropy:0.6130,  val_loss:0.6130,
# ....................................................................................................
# Epoch: 200, accuracy:0.6333,  binary_crossentropy:0.6191,  loss:0.6191,  val_accuracy:0.6670,  val_binary_crossentropy:0.5900,  val_loss:0.5900,
# ....................................................................................................
# Epoch: 300, accuracy:0.6409,  binary_crossentropy:0.6129,  loss:0.6129,  val_accuracy:0.6580,  val_binary_crossentropy:0.5845,  val_loss:0.5845,
# ....................................................................................................
# Epoch: 400, accuracy:0.6529,  binary_crossentropy:0.6086,  loss:0.6086,  val_accuracy:0.6600,  val_binary_crossentropy:0.5870,  val_loss:0.5870,
# ....................................................................................................
# Epoch: 500, accuracy:0.6519,  binary_crossentropy:0.6058,  loss:0.6058,  val_accuracy:0.6810,  val_binary_crossentropy:0.5821,  val_loss:0.5821,
# ....................................................................................................
# Epoch: 600, accuracy:0.6553,  binary_crossentropy:0.6021,  loss:0.6021,  val_accuracy:0.6840,  val_binary_crossentropy:0.5744,  val_loss:0.5744,
# ....................................................................................................
# Epoch: 700, accuracy:0.6604,  binary_crossentropy:0.6013,  loss:0.6013,  val_accuracy:0.6800,  val_binary_crossentropy:0.5703,  val_loss:0.5703,
# ....................................................................................................
# Epoch: 800, accuracy:0.6513,  binary_crossentropy:0.6035,  loss:0.6035,  val_accuracy:0.6930,  val_binary_crossentropy:0.5723,  val_loss:0.5723,
# ....................................................................................................
# Epoch: 900, accuracy:0.6594,  binary_crossentropy:0.6008,  loss:0.6008,  val_accuracy:0.6910,  val_binary_crossentropy:0.5705,  val_loss:0.5705,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6595,  binary_crossentropy:0.5993,  loss:0.5993,  val_accuracy:0.6850,  val_binary_crossentropy:0.5670,  val_loss:0.5670,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6617,  binary_crossentropy:0.5958,  loss:0.5958,  val_accuracy:0.6780,  val_binary_crossentropy:0.5656,  val_loss:0.5656,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6606,  binary_crossentropy:0.5961,  loss:0.5961,  val_accuracy:0.6930,  val_binary_crossentropy:0.5620,  val_loss:0.5620,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6582,  binary_crossentropy:0.5969,  loss:0.5969,  val_accuracy:0.6750,  val_binary_crossentropy:0.5599,  val_loss:0.5599,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6611,  binary_crossentropy:0.5931,  loss:0.5931,  val_accuracy:0.6720,  val_binary_crossentropy:0.5618,  val_loss:0.5618,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6532,  binary_crossentropy:0.5974,  loss:0.5974,  val_accuracy:0.6840,  val_binary_crossentropy:0.5524,  val_loss:0.5524,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6554,  binary_crossentropy:0.5949,  loss:0.5949,  val_accuracy:0.6840,  val_binary_crossentropy:0.5563,  val_loss:0.5563,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6583,  binary_crossentropy:0.5936,  loss:0.5936,  val_accuracy:0.6640,  val_binary_crossentropy:0.5633,  val_loss:0.5633,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6647,  binary_crossentropy:0.5913,  loss:0.5913,  val_accuracy:0.6840,  val_binary_crossentropy:0.5543,  val_loss:0.5543,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6595,  binary_crossentropy:0.5971,  loss:0.5971,  val_accuracy:0.6820,  val_binary_crossentropy:0.5573,  val_loss:0.5573,
# ....................................................................................................
# Epoch: 2000, accuracy:0.6625,  binary_crossentropy:0.5899,  loss:0.5899,  val_accuracy:0.6830,  val_binary_crossentropy:0.5575,  val_loss:0.5575,
# .................................................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
# Exception ignored in: 'zmq.backend.cython.message.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt

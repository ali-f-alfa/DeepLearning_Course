# %%
import numpy as np
import matplotlib.pyplot as plt

# define variable d
d_x = np.arange(1, 201)
d_y = np.concatenate([np.ones(100), np.ones(100) * -1])

# normal average
d_average = np.cumsum(y) / d_x

######################################## plotting
plt.figure(1, figsize=(12, 7.5))

# plot d 
plt.plot(d_x, d_y, linewidth = '4')

# plot average 
plt.plot(d_x, d_average, '-r', linewidth = '2')

# plot configurations
plt.xlim(0, 200)
plt.ylim(-1.5, 1.5)
plt.grid(axis = 'y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def m1(t):
    if (t == 0):
        return 0
    elif (t >= 0):
        return (beta * m1(t-1) + (1 - beta) * d_y[t])
    else:
        return "impossible"



# define variable d
d_x = np.arange(200)
d_y = np.concatenate([np.ones(100), np.ones(100) * -1])

# average2
beta = 0.9
d_average2 = []
for i in range(200):
    d_average2.append(m1(i))
######################################## plotting
plt.figure(1, figsize=(12, 7.5))

# plot d 
plt.plot(d_x, d_y, linewidth = '4')

# plot average 
plt.plot(d_x, d_average2, '-r', linewidth = '2')

# plot configurations
plt.xlim(0, 200)
plt.ylim(-1.5, 1.5)
plt.grid(axis = 'y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def m2(t):
    if (t == 0):
        return 0
    elif (t >= 1):
        return (d_average2[t] / (1 - beta**t))
    else:
        return "impossible"



# define variable d
d_x = np.arange(200)
d_y = np.concatenate([np.ones(100), np.ones(100) * -1])

# average3
beta = 0.9
d_average3 = []
for i in range(200):
    d_average3.append(m2(i))

######################################## plotting
plt.figure(1, figsize=(12, 7.5))

# plot d 
plt.plot(d_x, d_y, linewidth = '4')

# plot average 
plt.plot(d_x, d_average3, '-r', linewidth = '2')

# plot configurations
plt.xlim(-10, 200)
plt.ylim(-1.5, 1.5)
plt.grid(axis = 'y')
plt.show()

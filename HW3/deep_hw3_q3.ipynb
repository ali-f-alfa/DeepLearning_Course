# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random

random.seed (7)
np.random.seed(7)
tf.random.set_seed (7)

fashion_mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = fashion_mnist.load_data()


model = tf.keras.models.Sequential([tf.keras.layers.Flatten(), 
                                    tf.keras.layers.Dense(16, activation='relu'), 
                                    tf.keras.layers.Dense(10,activation='softmax')])
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer = opt,
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training
print("start training ...")
h = model.fit(training_images, training_labels, validation_split=0.1, epochs=50)

# testing
print("start testing ...")
test_loss, test_acc = model.evaluate(test_images, test_labels)

# plotting 
plt.figure(1, figsize=(12, 7.5))
plt.plot(h.history['loss'], label='Train Loss')
plt.plot(h.history['val_loss'], label='Validation Loss')
plt.show()
# Out:
# start training ...
# Epoch 1/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 6.2774 - accuracy: 0.1277 - val_loss: 2.3337 - val_accuracy: 0.1112
# Epoch 2/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 2.2996 - accuracy: 0.1237 - val_loss: 2.2715 - val_accuracy: 0.1147
# Epoch 3/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 2.1967 - accuracy: 0.1538 - val_loss: 2.1564 - val_accuracy: 0.1617
# Epoch 4/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 2.1233 - accuracy: 0.1787 - val_loss: 2.1256 - val_accuracy: 0.1723
# Epoch 5/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 2.0910 - accuracy: 0.1926 - val_loss: 2.0997 - val_accuracy: 0.1808
# Epoch 6/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 2.0671 - accuracy: 0.1997 - val_loss: 2.0961 - val_accuracy: 0.1962
# Epoch 7/50
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random

random.seed (7)
np.random.seed(7)
tf.random.set_seed (7)

fashion_mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = fashion_mnist.load_data()


model = tf.keras.models.Sequential([tf.keras.layers.Flatten(), 
                                    tf.keras.layers.Dense(32, activation='relu'), 
                                    tf.keras.layers.Dense(10,activation='softmax')])
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer = opt,
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training
print("start training ...")
h = model.fit(training_images, training_labels, validation_split=0.1, epochs=50)

# testing
print("start testing ...")
test_loss, test_acc = model.evaluate(test_images, test_labels)

# plotting 
plt.figure(1, figsize=(12, 7.5))
plt.plot(h.history['loss'], label='Train Loss')
plt.plot(h.history['val_loss'], label='Validation Loss')
plt.show()
# Out:
# start training ...
# Epoch 1/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 2.7558 - accuracy: 0.3217 - val_loss: 1.6686 - val_accuracy: 0.3827
# Epoch 2/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 1.5424 - accuracy: 0.4232 - val_loss: 1.2149 - val_accuracy: 0.5272
# Epoch 3/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 1.0596 - accuracy: 0.5822 - val_loss: 0.9721 - val_accuracy: 0.6040
# Epoch 4/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.9551 - accuracy: 0.6149 - val_loss: 0.8798 - val_accuracy: 0.6567
# Epoch 5/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.8569 - accuracy: 0.6520 - val_loss: 0.8935 - val_accuracy: 0.6515
# Epoch 6/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.8281 - accuracy: 0.6556 - val_loss: 0.8571 - val_accuracy: 0.6437
# Epoch 7/50
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random

random.seed (7)
np.random.seed(7)
tf.random.set_seed (7)

fashion_mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = fashion_mnist.load_data()


model = tf.keras.models.Sequential([tf.keras.layers.Flatten(), 
                                    tf.keras.layers.Dense(64, activation='relu'), 
                                    tf.keras.layers.Dense(10,activation='softmax')])
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer = opt,
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training
print("start training ...")
h = model.fit(training_images, training_labels, validation_split=0.1, epochs=50)

# testing
print("start testing ...")
test_loss, test_acc = model.evaluate(test_images, test_labels)

# plotting 
plt.figure(1, figsize=(12, 7.5))
plt.plot(h.history['loss'], label='Train Loss')
plt.plot(h.history['val_loss'], label='Validation Loss')
plt.show()
# Out:
# start training ...
# Epoch 1/50
# 1688/1688 [==============================] - 4s 2ms/step - loss: 11.5584 - accuracy: 0.6773 - val_loss: 5.6886 - val_accuracy: 0.7322
# Epoch 2/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 4.0647 - accuracy: 0.7594 - val_loss: 2.5613 - val_accuracy: 0.7133
# Epoch 3/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 1.6847 - accuracy: 0.6826 - val_loss: 1.4437 - val_accuracy: 0.7128
# Epoch 4/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 1.1218 - accuracy: 0.7166 - val_loss: 1.0264 - val_accuracy: 0.7125
# Epoch 5/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.8458 - accuracy: 0.7397 - val_loss: 0.8480 - val_accuracy: 0.7413
# Epoch 6/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.7224 - accuracy: 0.7639 - val_loss: 0.7566 - val_accuracy: 0.7725
# Epoch 7/50
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random

random.seed (7)
np.random.seed(7)
tf.random.set_seed (7)

fashion_mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = fashion_mnist.load_data()


model = tf.keras.models.Sequential([tf.keras.layers.Flatten(), 
                                    tf.keras.layers.Dense(128, activation='relu'), 
                                    tf.keras.layers.Dense(10,activation='softmax')])
opt = tf.keras.optimizers.SGD(learning_rate=0.0001)
model.compile(optimizer = opt,
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training
print("start training ...")
h = model.fit(training_images, training_labels, validation_split=0.1, epochs=50)

# testing
print("start testing ...")
test_loss, test_acc = model.evaluate(test_images, test_labels)

# plotting 
plt.figure(1, figsize=(12, 7.5))
plt.plot(h.history['loss'], label='Train Loss')
plt.plot(h.history['val_loss'], label='Validation Loss')
plt.show()
# Out:
# start training ...
# Epoch 1/50
# 1688/1688 [==============================] - 4s 2ms/step - loss: 5.6038 - accuracy: 0.6918 - val_loss: 1.5490 - val_accuracy: 0.7208
# Epoch 2/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 1.1912 - accuracy: 0.7273 - val_loss: 1.0604 - val_accuracy: 0.7302
# Epoch 3/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.8970 - accuracy: 0.7472 - val_loss: 0.8925 - val_accuracy: 0.7565
# Epoch 4/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.7862 - accuracy: 0.7609 - val_loss: 0.8242 - val_accuracy: 0.7707
# Epoch 5/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.7232 - accuracy: 0.7728 - val_loss: 0.7914 - val_accuracy: 0.7773
# Epoch 6/50
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.6800 - accuracy: 0.7801 - val_loss: 0.7511 - val_accuracy: 0.7850
# Epoch 7/50
# ...
